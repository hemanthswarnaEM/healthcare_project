# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from gensim.models import Word2Vec
import torch
import torch.nn as nn
import torch.optim as optim

# %%
file_path='/content/datafile.xlsx'
data_at_admission = pd.read_excel(file_path,sheet_name='Data-at-admission')
hlos = pd.read_excel(file_path,sheet_name='Hospital-length-of-stay')
hospital_df = pd.merge(left=data_at_admission,right=hlos[['parent_id','hospital_length_of_stay']],left_on='id',right_on='parent_id',how='left')

# %%
hospital_df.head()
# Out:
#    id                        reason_for_admission  age     sex ethnicity  \
# 0   1                               Fever [R50.9]   74    Male      "[]"
# 1   2                           Pneumonia [J18.9]   61  Female      "[]"
# 2   3                           Pneumonia [J18.9]   58  Female      "[]"
# 3   4  Suspected COVID-19 virus infection [U07.2]   94    Male      "[]"
# 4   5  Febrile respiratory illness [J98.9, R50.9]   91    Male      "[]"
#
#    ethnicity_other  height  weight  \
# 0              NaN     NaN     NaN
# 1              NaN   154.9    73.6
# 2              NaN     NaN     NaN
# 3              NaN   182.8    66.2
# 4              NaN     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  ...  ph  \
# 0  GERD (gastroesophageal reflux disease), Dement...  ... NaN
# 1  Closed fracture of fifth metatarsal bone, Dive...  ... NaN
# 2                                                NaN  ... NaN
# 3  Parkinson's Disease, Back pain, Benign Prostat...  ... NaN
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...  ... NaN
#
#    high_senstivity_cardiac_troponin esr  inr  ferritin d_dimer    crp  hs_crp  \
# 0                               NaN NaN  1.1       NaN     NaN  223.0     NaN
# 1                               NaN NaN  1.0       NaN    2354   95.6     NaN
# 2                               NaN NaN  NaN       NaN     NaN    NaN     NaN
# 3                               NaN NaN  NaN       NaN     NaN    NaN     NaN
# 4                               NaN NaN  NaN       NaN     NaN    NaN     NaN
#
#    parent_id  hospital_length_of_stay
# 0          1                       21
# 1          2                        5
# 2          3                        7
# 3          4                        9
# 4          5                        9
#
# [5 rows x 57 columns]

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 57 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                508 non-null    int64
#  1   reason_for_admission              508 non-null    object
#  2   age                               508 non-null    int64
#  3   sex                               508 non-null    object
#  4   ethnicity                         508 non-null    object
#  5   ethnicity_other                   0 non-null      float64
#  6   height                            272 non-null    float64
#  7   weight                            358 non-null    float64
#  8   comorbidities                     508 non-null    object
#  9   comorbidities_other               404 non-null    object
#  10  received_covid_vaccine            1 non-null      object
#  11  covid_vaccine                     0 non-null      float64
#  12  medications                       508 non-null    object
#  13  smoking_history                   296 non-null    object
#  14  year_they_quit                    43 non-null     float64
#  15  previous_er_visit_within_14_days  508 non-null    object
#  16  admission_disposition             508 non-null    object
#  17  systolic_blood_pressure           508 non-null    int64
#  18  diastolic_blood_pressure          508 non-null    int64
#  19  heart_rate                        508 non-null    int64
#  20  respiratory_rate                  508 non-null    int64
#  21  oxygen_saturation                 508 non-null    int64
#  22  temperature                       508 non-null    float64
#  23  motor                             506 non-null    float64
#  24  verbal                            506 non-null    float64
#  25  eye                               506 non-null    float64
#  26  intubated                         508 non-null    object
#  27  wbc                               506 non-null    float64
#  28  rbc                               506 non-null    float64
#  29  hemoglobin                        506 non-null    float64
#  30  hematocrit                        506 non-null    float64
#  31  mcv                               506 non-null    float64
#  32  mch                               506 non-null    float64
#  33  mchc                              506 non-null    float64
#  34  rdw                               506 non-null    float64
#  35  platelet_count                    506 non-null    float64
#  36  aptt_aptr                         288 non-null    object
#  37  pt                                315 non-null    float64
#  38  alt                               403 non-null    float64
#  39  ast                               403 non-null    float64
#  40  serum_creatinine                  506 non-null    float64
#  41  sodium                            506 non-null    float64
#  42  potassium                         506 non-null    float64
#  43  total_serum_bilirubin             403 non-null    float64
#  44  lactate                           362 non-null    float64
#  45  pao2                              32 non-null     float64
#  46  pao2_fio2                         23 non-null     float64
#  47  ph                                32 non-null     float64
#  48  high_senstivity_cardiac_troponin  0 non-null      float64
#  49  esr                               5 non-null      float64
#  50  inr                               315 non-null    float64
#  51  ferritin                          20 non-null     float64
#  52  d_dimer                           252 non-null    object
#  53  crp                               142 non-null    float64
#  54  hs_crp                            0 non-null      float64
#  55  parent_id                         508 non-null    int64
#  56  hospital_length_of_stay           508 non-null    int64
# dtypes: float64(35), int64(9), object(13)
# memory usage: 226.3+ KB

# %%
temp = """The variables age, sex, height, weight, comorbidities, comorbidities_other, systolic_blood_pressure, diastolic_blood_pressure, heart_rate, respiratory_rate, oxygen_saturation, temperature, motor, verbal, eye, wbc, rbc, hemoglobin, hematocrit, mcv, mch, mchc, rdw, platelet_count, aptt_aptr, pt, alt, ast, serum_creatinine, sodium, potassium, total_serum_bilirubin, lactate, pao2, pao2_fio2, ph, high_senstivity_cardiac_troponin, esr, inr, ferritin, d_dimer, crp, hs_crp, intubated, hospital_length_of_stay"""
variables = [var.strip() for var in temp.replace("The variables ", "").split(", ")]
variables
hospital_df = hospital_df[variables]
hospital_df.head()
# Out:
#    age     sex  height  weight  \
# 0   74    Male     NaN     NaN
# 1   61  Female   154.9    73.6
# 2   58  Female     NaN     NaN
# 3   94    Male   182.8    66.2
# 4   91    Male     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                                NaN                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...  ph  \
# 0                        62          85                20  ... NaN
# 1                        77          93                36  ... NaN
# 2                        72          73                24  ... NaN
# 3                        71          92                16  ... NaN
# 4                        76          60                18  ... NaN
#
#    high_senstivity_cardiac_troponin  esr  inr  ferritin  d_dimer    crp  \
# 0                               NaN  NaN  1.1       NaN      NaN  223.0
# 1                               NaN  NaN  1.0       NaN     2354   95.6
# 2                               NaN  NaN  NaN       NaN      NaN    NaN
# 3                               NaN  NaN  NaN       NaN      NaN    NaN
# 4                               NaN  NaN  NaN       NaN      NaN    NaN
#
#    hs_crp  intubated  hospital_length_of_stay
# 0     NaN         No                       21
# 1     NaN         No                        5
# 2     NaN         No                        7
# 3     NaN         No                        9
# 4     NaN         No                        9
#
# [5 rows x 45 columns]

# %%
hospital_df.isnull().sum()
# Out:
# age                                   0
# sex                                   0
# height                              236
# weight                              150
# comorbidities                         0
# comorbidities_other                 104
# systolic_blood_pressure               0
# diastolic_blood_pressure              0
# heart_rate                            0
# respiratory_rate                      0
# oxygen_saturation                     0
# temperature                           0
# motor                                 2
# verbal                                2
# eye                                   2
# wbc                                   2
# rbc                                   2
# hemoglobin                            2
# hematocrit                            2
# mcv                                   2
# mch                                   2
# mchc                                  2
# rdw                                   2
# platelet_count                        2
# aptt_aptr                           220
# pt                                  193
# alt                                 105
# ast                                 105
# serum_creatinine                      2
# sodium                                2
# potassium                             2
# total_serum_bilirubin               105
# lactate                             146
# pao2                                476
# pao2_fio2                           485
# ph                                  476
# high_senstivity_cardiac_troponin    508
# esr                                 503
# inr                                 193
# ferritin                            488
# d_dimer                             256
# crp                                 366
# hs_crp                              508
# intubated                             0
# hospital_length_of_stay               0
# dtype: int64

# %%
hospital_df.nunique()
# Out:
# age                                  76
# sex                                   2
# height                               69
# weight                              203
# comorbidities                       137
# comorbidities_other                 359
# systolic_blood_pressure             100
# diastolic_blood_pressure             65
# heart_rate                           83
# respiratory_rate                     28
# oxygen_saturation                    34
# temperature                          49
# motor                                 6
# verbal                                5
# eye                                   4
# wbc                                 133
# rbc                                 237
# hemoglobin                           90
# hematocrit                          192
# mcv                                 232
# mch                                 119
# mchc                                 66
# rdw                                  79
# platelet_count                      253
# aptt_aptr                            34
# pt                                   72
# alt                                 112
# ast                                 111
# serum_creatinine                    161
# sodium                               36
# potassium                            33
# total_serum_bilirubin                31
# lactate                              50
# pao2                                 10
# pao2_fio2                             1
# ph                                   22
# high_senstivity_cardiac_troponin      0
# esr                                   5
# inr                                  22
# ferritin                             20
# d_dimer                             213
# crp                                 129
# hs_crp                                0
# intubated                             2
# hospital_length_of_stay              54
# dtype: int64

# %%
threshold = 0.3 * 508
hospital_df = hospital_df.dropna(thresh=threshold, axis=1)
hospital_df.head()
# Out:
#    age     sex  height  weight  \
# 0   74    Male     NaN     NaN
# 1   61  Female   154.9    73.6
# 2   58  Female     NaN     NaN
# 3   94    Male   182.8    66.2
# 4   91    Male     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                                NaN                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...   ast  \
# 0                        62          85                20  ...  49.0
# 1                        77          93                36  ...  68.0
# 2                        72          73                24  ...  76.0
# 3                        71          92                16  ...  24.0
# 4                        76          60                18  ...  26.0
#
#    serum_creatinine  sodium  potassium  total_serum_bilirubin  lactate  inr  \
# 0             165.0   135.0        3.9                   10.0      2.3  1.1
# 1              49.0   137.0        3.8                   12.0      1.5  1.0
# 2              71.0   135.0        3.7                    7.0      1.0  NaN
# 3             146.0   135.0        2.8                   10.0      4.5  NaN
# 4             109.0   142.0        3.8                   19.0      3.2  NaN
#
#    d_dimer  intubated  hospital_length_of_stay
# 0      NaN         No                       21
# 1     2354         No                        5
# 2      NaN         No                        7
# 3      NaN         No                        9
# 4      NaN         No                        9
#
# [5 rows x 37 columns]

# %%
hospital_df['aptt_aptr'] = pd.to_numeric(hospital_df['aptt_aptr'], errors='coerce')
hospital_df['d_dimer'] = pd.to_numeric(hospital_df['d_dimer'], errors='coerce')

# Convert 'sex' column: map male to 1, female to 0
hospital_df['sex'] = hospital_df['sex'].map({'Male': 1, 'Female': 0})

# Convert 'intubated' column: map yes to 1, no to 0
hospital_df['intubated'] = hospital_df['intubated'].map({'Yes': 1, 'No': 0})

hospital_df.head()
# Out:
# <ipython-input-143-fbc46943c7b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['aptt_aptr'] = pd.to_numeric(hospital_df['aptt_aptr'], errors='coerce')
# <ipython-input-143-fbc46943c7b2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['d_dimer'] = pd.to_numeric(hospital_df['d_dimer'], errors='coerce')
# <ipython-input-143-fbc46943c7b2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['sex'] = hospital_df['sex'].map({'Male': 1, 'Female': 0})
# <ipython-input-143-fbc46943c7b2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df['intubated'] = hospital_df['intubated'].map({'Yes': 1, 'No': 0})
#    age  sex  height  weight  \
# 0   74    1     NaN     NaN
# 1   61    0   154.9    73.6
# 2   58    0     NaN     NaN
# 3   94    1   182.8    66.2
# 4   91    1     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                                NaN                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...   ast  \
# 0                        62          85                20  ...  49.0
# 1                        77          93                36  ...  68.0
# 2                        72          73                24  ...  76.0
# 3                        71          92                16  ...  24.0
# 4                        76          60                18  ...  26.0
#
#    serum_creatinine  sodium  potassium  total_serum_bilirubin  lactate  inr  \
# 0             165.0   135.0        3.9                   10.0      2.3  1.1
# 1              49.0   137.0        3.8                   12.0      1.5  1.0
# 2              71.0   135.0        3.7                    7.0      1.0  NaN
# 3             146.0   135.0        2.8                   10.0      4.5  NaN
# 4             109.0   142.0        3.8                   19.0      3.2  NaN
#
#    d_dimer  intubated  hospital_length_of_stay
# 0      NaN          0                       21
# 1   2354.0          0                        5
# 2      NaN          0                        7
# 3      NaN          0                        9
# 4      NaN          0                        9
#
# [5 rows x 37 columns]

# %%
num_cols = hospital_df.select_dtypes(include=['float64', 'int64']).columns

knn_cols = ['aptt_aptr', 'pt']
other_numerical_cols = [col for col in num_cols if col not in knn_cols]
hospital_df[other_numerical_cols] = hospital_df[other_numerical_cols].fillna(hospital_df[other_numerical_cols].median())
epochee = lambda num: (num + 5) * 10
catageroical_cols = hospital_df.select_dtypes(include=['object']).columns
hospital_df[catageroical_cols] = hospital_df[catageroical_cols].fillna(hospital_df[catageroical_cols].mode().iloc[0])
# Out:
# <ipython-input-144-b1a8f9e58e1b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df[other_numerical_cols] = hospital_df[other_numerical_cols].fillna(hospital_df[other_numerical_cols].median())
# <ipython-input-144-b1a8f9e58e1b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_df[catageroical_cols] = hospital_df[catageroical_cols].fillna(hospital_df[catageroical_cols].mode().iloc[0])

# %%
null_values_after_imputation =hospital_df.isnull().sum()


print("Null values after KNN and median/mode imputation:\n", null_values_after_imputation)
# Out:
# Null values after KNN and median/mode imputation:
#  age                           0
# sex                           0
# height                        0
# weight                        0
# comorbidities                 0
# comorbidities_other           0
# systolic_blood_pressure       0
# diastolic_blood_pressure      0
# heart_rate                    0
# respiratory_rate              0
# oxygen_saturation             0
# temperature                   0
# motor                         0
# verbal                        0
# eye                           0
# wbc                           0
# rbc                           0
# hemoglobin                    0
# hematocrit                    0
# mcv                           0
# mch                           0
# mchc                          0
# rdw                           0
# platelet_count                0
# aptt_aptr                   221
# pt                          193
# alt                           0
# ast                           0
# serum_creatinine              0
# sodium                        0
# potassium                     0
# total_serum_bilirubin         0
# lactate                       0
# inr                           0
# d_dimer                       0
# intubated                     0
# hospital_length_of_stay       0
# dtype: int64

# %%
numerical_means = hospital_df.drop(columns=['sex', 'intubated']).select_dtypes(include=['number']).mean()
epochee = lambda num: (num + 5) * 10
categorical_unique_values = hospital_df.drop(columns=['sex', 'intubated']).select_dtypes(include=['object', 'category']).nunique()
sex_counts = hospital_df['sex'].value_counts().rename(index={1: 'Male', 0: 'Female'})

intubated_counts = hospital_df['intubated'].value_counts().rename(index={1: 'Yes', 0: 'No'})

# %%
from sklearn.impute import KNNImputer
knn_imputer = KNNImputer(n_neighbors=5)  # Using 5 neighbors by default

hospital_df[knn_cols] = knn_imputer.fit_transform(hospital_df[knn_cols])

# %%
hospital_df.head()
# Out:
#    age  sex  height  weight  \
# 0   74    1   167.6    76.7
# 1   61    0   154.9    73.6
# 2   58    0   167.6    76.7
# 3   94    1   182.8    66.2
# 4   91    1   167.6    76.7
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                       Dyslipidemia                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...   ast  \
# 0                        62          85                20  ...  49.0
# 1                        77          93                36  ...  68.0
# 2                        72          73                24  ...  76.0
# 3                        71          92                16  ...  24.0
# 4                        76          60                18  ...  26.0
#
#    serum_creatinine  sodium  potassium  total_serum_bilirubin  lactate  inr  \
# 0             165.0   135.0        3.9                   10.0      2.3  1.1
# 1              49.0   137.0        3.8                   12.0      1.5  1.0
# 2              71.0   135.0        3.7                    7.0      1.0  1.0
# 3             146.0   135.0        2.8                   10.0      4.5  1.0
# 4             109.0   142.0        3.8                   19.0      3.2  1.0
#
#    d_dimer  intubated  hospital_length_of_stay
# 0   1018.0          0                       21
# 1   2354.0          0                        5
# 2   1018.0          0                        7
# 3   1018.0          0                        9
# 4   1018.0          0                        9
#
# [5 rows x 37 columns]

# %%
hospital_df.nunique()
# Out:
# age                          76
# sex                           2
# height                       69
# weight                      204
# comorbidities               137
# comorbidities_other         359
# systolic_blood_pressure     100
# diastolic_blood_pressure     65
# heart_rate                   83
# respiratory_rate             28
# oxygen_saturation            34
# temperature                  49
# motor                         6
# verbal                        5
# eye                           4
# wbc                         133
# rbc                         238
# hemoglobin                   90
# hematocrit                  192
# mcv                         232
# mch                         119
# mchc                         66
# rdw                          80
# platelet_count              253
# aptt_aptr                    47
# pt                           76
# alt                         112
# ast                         111
# serum_creatinine            161
# sodium                       36
# potassium                    33
# total_serum_bilirubin        31
# lactate                      51
# inr                          22
# d_dimer                     212
# intubated                     2
# hospital_length_of_stay      54
# dtype: int64

# %%
def preprocess_text(text):
    # Preprocess comorbidities text (you can adjust based on your data)
    return text.lower().split()

hospital_df['comorbidities_processed'] = hospital_df['comorbidities_other'].apply(preprocess_text)

word2vec_model = Word2Vec(sentences=hospital_df['comorbidities_processed'], vector_size=50, window=5, min_count=1, workers=4)
hospital_df['comorbidities_vec'] = hospital_df['comorbidities_processed'].apply(lambda x: np.mean([word2vec_model.wv[word] for word in x if word in word2vec_model.wv], axis=0))

hospital_df = hospital_df.dropna(subset=['comorbidities_vec'])

# %%
hospital_df.head()
hospital_df.isnull().sum()
# Out:
#    age  sex  height  weight  \
# 0   74    1   167.6    76.7
# 1   61    0   154.9    73.6
# 2   58    0   167.6    76.7
# 3   94    1   182.8    66.2
# 4   91    1   167.6    76.7
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                       Dyslipidemia                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...  sodium  \
# 0                        62          85                20  ...   135.0
# 1                        77          93                36  ...   137.0
# 2                        72          73                24  ...   135.0
# 3                        71          92                16  ...   135.0
# 4                        76          60                18  ...   142.0
#
#    potassium  total_serum_bilirubin  lactate  inr  d_dimer  intubated  \
# 0        3.9                   10.0      2.3  1.1   1018.0          0
# 1        3.8                   12.0      1.5  1.0   2354.0          0
# 2        3.7                    7.0      1.0  1.0   1018.0          0
# 3        2.8                   10.0      4.5  1.0   1018.0          0
# 4        3.8                   19.0      3.2  1.0   1018.0          0
#
#    hospital_length_of_stay                            comorbidities_processed  \
# 0                       21  [gerd, (gastroesophageal, reflux, disease),, d...
# 1                        5  [closed, fracture, of, fifth, metatarsal, bone...
# 2                        7                                     [dyslipidemia]
# 3                        9  [parkinson's, disease,, back, pain,, benign, p...
# 4                        9  [tavi,, atrial, fibrillation,, gastric, reflux...
#
#                                    comorbidities_vec
# 0  [-0.0019518099, 0.00044901887, 0.004173615, -0...
# 1  [0.0049844757, 0.006182187, -0.0023723156, 0.0...
# 2  [-0.0011411794, 0.0004133377, 0.010223488, 0.0...
# 3  [-0.0013800903, 0.0044691465, 0.003095696, 0.0...
# 4  [-0.005155638, -0.008734879, -0.007390146, -0....
#
# [5 rows x 39 columns]

# %%
hospital_df = hospital_df.dropna(subset=['comorbidities_vec'])

# %%
hospital_df.head()
hospital_df.isnull().sum()
# Out:
#    age  sex  height  weight  \
# 0   74    1   167.6    76.7
# 1   61    0   154.9    73.6
# 2   58    0   167.6    76.7
# 3   94    1   182.8    66.2
# 4   91    1   167.6    76.7
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  systolic_blood_pressure  \
# 0  GERD (gastroesophageal reflux disease), Dement...                       99
# 1  Closed fracture of fifth metatarsal bone, Dive...                      122
# 2                                       Dyslipidemia                      109
# 3  Parkinson's Disease, Back pain, Benign Prostat...                      165
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...                      131
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  ...  sodium  \
# 0                        62          85                20  ...   135.0
# 1                        77          93                36  ...   137.0
# 2                        72          73                24  ...   135.0
# 3                        71          92                16  ...   135.0
# 4                        76          60                18  ...   142.0
#
#    potassium  total_serum_bilirubin  lactate  inr  d_dimer  intubated  \
# 0        3.9                   10.0      2.3  1.1   1018.0          0
# 1        3.8                   12.0      1.5  1.0   2354.0          0
# 2        3.7                    7.0      1.0  1.0   1018.0          0
# 3        2.8                   10.0      4.5  1.0   1018.0          0
# 4        3.8                   19.0      3.2  1.0   1018.0          0
#
#    hospital_length_of_stay                            comorbidities_processed  \
# 0                       21  [gerd, (gastroesophageal, reflux, disease),, d...
# 1                        5  [closed, fracture, of, fifth, metatarsal, bone...
# 2                        7                                     [dyslipidemia]
# 3                        9  [parkinson's, disease,, back, pain,, benign, p...
# 4                        9  [tavi,, atrial, fibrillation,, gastric, reflux...
#
#                                    comorbidities_vec
# 0  [-0.0019518099, 0.00044901887, 0.004173615, -0...
# 1  [0.0049844757, 0.006182187, -0.0023723156, 0.0...
# 2  [-0.0011411794, 0.0004133377, 0.010223488, 0.0...
# 3  [-0.0013800903, 0.0044691465, 0.003095696, 0.0...
# 4  [-0.005155638, -0.008734879, -0.007390146, -0....
#
# [5 rows x 39 columns]

# %%
hospital_df.to_csv('preprocessed_data.csv', index=False)

# %%
if 'comorbidities_vec' in hospital_df.columns:
    hospital_df = hospital_df.drop(columns=['comorbidities_other'])

# %%
def categorize_comorbidities(comorbidity):
    if 'cardiac' in comorbidity:
        return 'Cardiovascular'
    elif 'diabetes' in comorbidity:
        return 'Metabolic'
    elif 'respiratory' in comorbidity:
        return 'Respiratory'
    else:
        return 'Other'

hospital_df['comorbidities_category'] = hospital_df['comorbidities'].apply(categorize_comorbidities)

# %%
from sklearn.preprocessing import OneHotEncoder

hospital_df['comorbidities_category'] = hospital_df['comorbidities'].apply(categorize_comorbidities)

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
comorbidities_encoded = encoder.fit_transform(hospital_df[['comorbidities_category']])
comorbidities_encoded_df = pd.DataFrame(comorbidities_encoded, columns=encoder.get_feature_names_out(['comorbidities_category']))

hospital_df = hospital_df.drop(columns=['comorbidities'])
hospital_df = pd.concat([hospital_df, comorbidities_encoded_df], axis=1)

# %%
numerical_features = hospital_df.select_dtypes(include=['float64', 'int64']).columns
for column in numerical_features:
  hospital_df[column] = hospital_df[column].fillna(hospital_df[column].median())

# %%
scaler = StandardScaler()
hospital_df[numerical_features] = scaler.fit_transform(hospital_df[numerical_features])

# %%
hospital_df.head()
# Out:
#         age       sex    height    weight  systolic_blood_pressure  \
# 0  0.486777  0.846296  0.046033 -0.136901                -1.378253
# 1 -0.306970 -1.181620 -1.538752 -0.305780                -0.334198
# 2 -0.490142 -1.181620  0.046033 -0.136901                -0.924316
# 3  1.707926  0.846296  1.942784 -0.708911                 1.617732
# 4  1.524754  0.846296  0.046033 -0.136901                 0.074346
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  oxygen_saturation  \
# 0                 -1.056722   -0.708594         -0.684234          -0.016469
# 1                  0.111621   -0.251350          1.549282          -0.836679
# 2                 -0.277826   -1.394461         -0.125855          -0.344553
# 3                 -0.355716   -0.308505         -1.242613           0.475657
# 4                  0.033732   -2.137484         -0.963423           0.311615
#
#    temperature  ...   lactate       inr   d_dimer  intubated  \
# 0    -0.278453  ...  0.047269  0.002199 -0.228143   -0.17443
# 1     0.240835  ... -0.709029 -0.183965  2.104986   -0.17443
# 2     0.552408  ... -1.181715 -0.183965 -0.228143   -0.17443
# 3    -0.278453  ...  2.127088 -0.183965 -0.228143   -0.17443
# 4     0.448550  ...  0.898104 -0.183965 -0.228143   -0.17443
#
#    hospital_length_of_stay                            comorbidities_processed  \
# 0                 0.720477  [gerd, (gastroesophageal, reflux, disease),, d...
# 1                -0.625120  [closed, fracture, of, fifth, metatarsal, bone...
# 2                -0.456920                                     [dyslipidemia]
# 3                -0.288721  [parkinson's, disease,, back, pain,, benign, p...
# 4                -0.288721  [tavi,, atrial, fibrillation,, gastric, reflux...
#
#                                    comorbidities_vec  comorbidities_category  \
# 0  [-0.0019518099, 0.00044901887, 0.004173615, -0...                   Other
# 1  [0.0049844757, 0.006182187, -0.0023723156, 0.0...                   Other
# 2  [-0.0011411794, 0.0004133377, 0.010223488, 0.0...                   Other
# 3  [-0.0013800903, 0.0044691465, 0.003095696, 0.0...                   Other
# 4  [-0.005155638, -0.008734879, -0.007390146, -0....          Cardiovascular
#
#    comorbidities_category_Cardiovascular  comorbidities_category_Other
# 0                              -0.457738                      0.457738
# 1                              -0.457738                      0.457738
# 2                              -0.457738                      0.457738
# 3                              -0.457738                      0.457738
# 4                               2.184657                     -2.184657
#
# [5 rows x 40 columns]

# %%
hospital_df.isnull().sum()
hospital_df.describe()

hospital_df.to_csv('preprocessed_data.csv', index=False)

# %%
hospital_df = hospital_df.drop(columns=['comorbidities_processed', 'comorbidities_category'], errors='ignore')

hospital_df.head()
# Out:
#         age       sex    height    weight  systolic_blood_pressure  \
# 0  0.486777  0.846296  0.046033 -0.136901                -1.378253
# 1 -0.306970 -1.181620 -1.538752 -0.305780                -0.334198
# 2 -0.490142 -1.181620  0.046033 -0.136901                -0.924316
# 3  1.707926  0.846296  1.942784 -0.708911                 1.617732
# 4  1.524754  0.846296  0.046033 -0.136901                 0.074346
#
#    diastolic_blood_pressure  heart_rate  respiratory_rate  oxygen_saturation  \
# 0                 -1.056722   -0.708594         -0.684234          -0.016469
# 1                  0.111621   -0.251350          1.549282          -0.836679
# 2                 -0.277826   -1.394461         -0.125855          -0.344553
# 3                 -0.355716   -0.308505         -1.242613           0.475657
# 4                  0.033732   -2.137484         -0.963423           0.311615
#
#    temperature  ...  potassium  total_serum_bilirubin   lactate       inr  \
# 0    -0.278453  ...   0.026926              -0.057389  0.047269  0.002199
# 1     0.240835  ...  -0.163049               0.333936 -0.709029 -0.183965
# 2     0.552408  ...  -0.353024              -0.644377 -1.181715 -0.183965
# 3    -0.278453  ...  -2.062794              -0.057389  2.127088 -0.183965
# 4     0.448550  ...  -0.163049               1.703574  0.898104 -0.183965
#
#     d_dimer  intubated  hospital_length_of_stay  \
# 0 -0.228143   -0.17443                 0.720477
# 1  2.104986   -0.17443                -0.625120
# 2 -0.228143   -0.17443                -0.456920
# 3 -0.228143   -0.17443                -0.288721
# 4 -0.228143   -0.17443                -0.288721
#
#                                    comorbidities_vec  \
# 0  [-0.0019518099, 0.00044901887, 0.004173615, -0...
# 1  [0.0049844757, 0.006182187, -0.0023723156, 0.0...
# 2  [-0.0011411794, 0.0004133377, 0.010223488, 0.0...
# 3  [-0.0013800903, 0.0044691465, 0.003095696, 0.0...
# 4  [-0.005155638, -0.008734879, -0.007390146, -0....
#
#    comorbidities_category_Cardiovascular  comorbidities_category_Other
# 0                              -0.457738                      0.457738
# 1                              -0.457738                      0.457738
# 2                              -0.457738                      0.457738
# 3                              -0.457738                      0.457738
# 4                               2.184657                     -2.184657
#
# [5 rows x 38 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
sns.histplot(hospital_df['hospital_length_of_stay'], bins=50, kde=True)
plt.title('(HLOS)')
plt.xlabel('Hospital Length of Stay')
plt.ylabel('Frequency')
plt.show()

if hospital_df['hospital_length_of_stay'].skew() > 1:
    hospital_df['log_hlos'] = np.log1p(hospital_df['hospital_length_of_stay'])
    target = 'log_hlos'
else:
    target = 'hospital_length_of_stay'

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=hospital_df, y='hospital_length_of_stay')
plt.title('Boxplot of Hospital Length of Stay')
plt.ylabel('Hospital Length of Stay')
plt.grid(True)
plt.show()

# %%
categorical_cols = ['sex', 'intubated']

plt.figure(figsize=(12, 8))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(1, 2, i)
    sns.countplot(x=col, data=hospital_df)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix = hospital_df.select_dtypes(include=np.number).corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

correlations = corr_matrix[target].abs().sort_values(ascending=False)
high_features = correlations[1:16].index.tolist()

print("Top features selected based on correlation with target:")
print(high_features)
# Out:
# Top features selected based on correlation with target:
# ['hospital_length_of_stay', 'age', 'platelet_count', 'mcv', 'oxygen_saturation', 'height', 'lactate', 'wbc', 'mch', 'rbc', 'serum_creatinine', 'total_serum_bilirubin', 'ast', 'temperature', 'diastolic_blood_pressure']

# %%
X = hospital_df[high_features]
y = hospital_df[target]

# %%
from keras.layers import Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
def build_model(input_dim, dropout_rate, learning_rate):
    model = Sequential()
    model.add(Dense(128, input_dim=input_dim, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))

    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate / 2))

    model.add(Dense(32, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate / 4))

    model.add(Dense(1))

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mse'])
    return model

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
num_trials = 5
train_mse_list = []
test_mse_list = []

learning_rates = [0.0005, 0.0001]
dropout_rates = [0.1, 0.2]

best_mse = float('inf')
best_params = {}

for lr in learning_rates:
    for dr in dropout_rates:
        print(f"Learning Rate: {lr}, Dropout Rate: {dr}")


        for trial in range(num_trials):
            print(f"Trial {trial + 1}/{num_trials}")

            X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=trial)

            model = build_model(input_dim=X_train.shape[1], dropout_rate=dr, learning_rate=lr)


            early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
            reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

            trained_model = model.fit(X_train, y_train, epochs=500, batch_size=64, validation_split=0.2,
                                      callbacks=[early_stopping, reduce_lr], verbose=0)

            y_train_pred = model.predict(X_train).flatten()
            y_test_pred = model.predict(X_test).flatten()


            train_mse = mean_squared_error(y_train, y_train_pred)
            test_mse = mean_squared_error(y_test, y_test_pred)

            train_mse_list.append(train_mse)
            test_mse_list.append(test_mse)

            print(f"Train MSE: {train_mse:.4f}, Test MSE: {test_mse:.4f}")

            if test_mse < best_mse:
                best_mse = test_mse
                best_params = {'learning_rate': lr, 'dropout_rate': dr}

mean_train_mse = np.mean(train_mse_list)
std_train_mse = np.std(train_mse_list)
mean_test_mse = np.mean(test_mse_list)
std_test_mse = np.std(test_mse_list)

print(f"Average Train MSE: {mean_train_mse:.4f}, Std Dev Train MSE: {std_train_mse:.4f}")
print(f"Average Test MSE: {mean_test_mse:.4f}, Std Dev Test MSE: {std_test_mse:.4f}")
print(f"Best Hyperparameters: {best_params}")
print(f"Best Test MSE: {best_mse}")
# Out:
# Learning Rate: 0.0005, Dropout Rate: 0.1
# Trial 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 22 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bfc33cc67a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MSE: 0.3035, Test MSE: 0.5017
# Trial 2/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.1429, Test MSE: 0.3667
# Trial 3/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MSE: 0.1142, Test MSE: 0.4091
# Trial 4/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MSE: 0.1845, Test MSE: 0.4387
# Trial 5/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.1143, Test MSE: 0.4547
# Learning Rate: 0.0005, Dropout Rate: 0.2
# Trial 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.1752, Test MSE: 0.4052
# Trial 2/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.1590, Test MSE: 0.3097
# Trial 3/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.0950, Test MSE: 0.2584
# Trial 4/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.2026, Test MSE: 0.3817
# Trial 5/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Train MSE: 0.1250, Test MSE: 0.3449
# Learning Rate: 0.0001, Dropout Rate: 0.1
# Trial 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.8059, Test MSE: 0.8497
# Trial 2/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 1.1220, Test MSE: 0.9571
# Trial 3/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.9866, Test MSE: 0.9753
# Trial 4/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.9953, Test MSE: 1.1612
# Trial 5/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Train MSE: 0.4383, Test MSE: 0.7288
# Learning Rate: 0.0001, Dropout Rate: 0.2
# Trial 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Train MSE: 1.1274, Test MSE: 1.1121
# Trial 2/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.8065, Test MSE: 0.8275
# Trial 3/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.3706, Test MSE: 1.0958
# Trial 4/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train MSE: 0.5793, Test MSE: 0.9979
# Trial 5/5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train MSE: 0.8301, Test MSE: 0.8966
# Average Train MSE: 0.4839, Std Dev Train MSE: 0.3714
# Average Test MSE: 0.6736, Std Dev Test MSE: 0.3049
# Best Hyperparameters: {'learning_rate': 0.0005, 'dropout_rate': 0.2}
# Best Test MSE: 0.2584490576315693

# %%
final_model = build_model(input_dim=X_train.shape[1], dropout_rate=best_params['dropout_rate'], learning_rate=best_params['learning_rate'])

history = final_model.fit(X_train, y_train, epochs=500, batch_size=64, validation_split=0.2, callbacks=[early_stopping, reduce_lr], verbose=1)
y_test_pred = final_model.predict(X_test).flatten()
if target == 'log_hlos':
    y_test_pred = np.expm1(y_test_pred)
    y_test_actual = np.expm1(y_test)
else:
    y_test_actual = y_test
mse = mean_squared_error(y_test_actual, y_test_pred)
r2 = r2_score(y_test_actual, y_test_pred)

print(f"Final MSE (Test): {mse:.4f}")
print(f"Final R2 score (Test): {r2:.4f}")
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.7430 - mse: 1.7430 - val_loss: 1.1034 - val_mse: 1.1034 - learning_rate: 5.0000e-04
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5351 - mse: 1.5351 - val_loss: 1.0165 - val_mse: 1.0165 - learning_rate: 5.0000e-04
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5316 - mse: 1.5316 - val_loss: 0.9486 - val_mse: 0.9486 - learning_rate: 5.0000e-04
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2740 - mse: 1.2740 - val_loss: 0.8874 - val_mse: 0.8874 - learning_rate: 5.0000e-04
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2314 - mse: 1.2314 - val_loss: 0.8312 - val_mse: 0.8312 - learning_rate: 5.0000e-04
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2007 - mse: 1.2007 - val_loss: 0.7814 - val_mse: 0.7814 - learning_rate: 5.0000e-04
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0751 - mse: 1.0751 - val_loss: 0.7366 - val_mse: 0.7366 - learning_rate: 5.0000e-04
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0414 - mse: 1.0414 - val_loss: 0.7014 - val_mse: 0.7014 - learning_rate: 5.0000e-04
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8624 - mse: 0.8624 - val_loss: 0.6644 - val_mse: 0.6644 - learning_rate: 5.0000e-04
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8569 - mse: 0.8569 - val_loss: 0.6377 - val_mse: 0.6377 - learning_rate: 5.0000e-04
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7654 - mse: 0.7654 - val_loss: 0.6082 - val_mse: 0.6082 - learning_rate: 5.0000e-04
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8306 - mse: 0.8306 - val_loss: 0.5825 - val_mse: 0.5825 - learning_rate: 5.0000e-04
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7720 - mse: 0.7720 - val_loss: 0.5569 - val_mse: 0.5569 - learning_rate: 5.0000e-04
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7813 - mse: 0.7813 - val_loss: 0.5360 - val_mse: 0.5360 - learning_rate: 5.0000e-04
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6833 - mse: 0.6833 - val_loss: 0.5180 - val_mse: 0.5180 - learning_rate: 5.0000e-04
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6908 - mse: 0.6908 - val_loss: 0.4995 - val_mse: 0.4995 - learning_rate: 5.0000e-04
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7085 - mse: 0.7085 - val_loss: 0.4829 - val_mse: 0.4829 - learning_rate: 5.0000e-04
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6712 - mse: 0.6712 - val_loss: 0.4698 - val_mse: 0.4698 - learning_rate: 5.0000e-04
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6667 - mse: 0.6667 - val_loss: 0.4543 - val_mse: 0.4543 - learning_rate: 5.0000e-04
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6691 - mse: 0.6691 - val_loss: 0.4429 - val_mse: 0.4429 - learning_rate: 5.0000e-04
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6809 - mse: 0.6809 - val_loss: 0.4362 - val_mse: 0.4362 - learning_rate: 5.0000e-04
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6047 - mse: 0.6047 - val_loss: 0.4251 - val_mse: 0.4251 - learning_rate: 5.0000e-04
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5967 - mse: 0.5967 - val_loss: 0.4163 - val_mse: 0.4163 - learning_rate: 5.0000e-04
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7400 - mse: 0.7400 - val_loss: 0.4041 - val_mse: 0.4041 - learning_rate: 5.0000e-04
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5252 - mse: 0.5252 - val_loss: 0.3935 - val_mse: 0.3935 - learning_rate: 5.0000e-04
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7855 - mse: 0.7855 - val_loss: 0.3847 - val_mse: 0.3847 - learning_rate: 5.0000e-04
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5413 - mse: 0.5413 - val_loss: 0.3766 - val_mse: 0.3766 - learning_rate: 5.0000e-04
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6400 - mse: 0.6400 - val_loss: 0.3733 - val_mse: 0.3733 - learning_rate: 5.0000e-04
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5638 - mse: 0.5638 - val_loss: 0.3606 - val_mse: 0.3606 - learning_rate: 5.0000e-04
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4750 - mse: 0.4750 - val_loss: 0.3442 - val_mse: 0.3442 - learning_rate: 5.0000e-04
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4546 - mse: 0.4546 - val_loss: 0.3355 - val_mse: 0.3355 - learning_rate: 5.0000e-04
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5095 - mse: 0.5095 - val_loss: 0.3328 - val_mse: 0.3328 - learning_rate: 5.0000e-04
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5698 - mse: 0.5698 - val_loss: 0.3283 - val_mse: 0.3283 - learning_rate: 5.0000e-04
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5520 - mse: 0.5520 - val_loss: 0.3236 - val_mse: 0.3236 - learning_rate: 5.0000e-04
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6030 - mse: 0.6030 - val_loss: 0.3214 - val_mse: 0.3214 - learning_rate: 5.0000e-04
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6436 - mse: 0.6436 - val_loss: 0.3180 - val_mse: 0.3180 - learning_rate: 5.0000e-04
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5377 - mse: 0.5377 - val_loss: 0.3122 - val_mse: 0.3122 - learning_rate: 5.0000e-04
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5621 - mse: 0.5621 - val_loss: 0.3098 - val_mse: 0.3098 - learning_rate: 5.0000e-04
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5520 - mse: 0.5520 - val_loss: 0.3027 - val_mse: 0.3027 - learning_rate: 5.0000e-04
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5380 - mse: 0.5380 - val_loss: 0.2992 - val_mse: 0.2992 - learning_rate: 5.0000e-04
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5077 - mse: 0.5077 - val_loss: 0.2966 - val_mse: 0.2966 - learning_rate: 5.0000e-04
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4340 - mse: 0.4340 - val_loss: 0.2922 - val_mse: 0.2922 - learning_rate: 5.0000e-04
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4202 - mse: 0.4202 - val_loss: 0.2889 - val_mse: 0.2889 - learning_rate: 5.0000e-04
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5041 - mse: 0.5041 - val_loss: 0.2878 - val_mse: 0.2878 - learning_rate: 5.0000e-04
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4443 - mse: 0.4443 - val_loss: 0.2876 - val_mse: 0.2876 - learning_rate: 5.0000e-04
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4857 - mse: 0.4857 - val_loss: 0.2906 - val_mse: 0.2906 - learning_rate: 5.0000e-04
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4551 - mse: 0.4551 - val_loss: 0.2931 - val_mse: 0.2931 - learning_rate: 5.0000e-04
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4541 - mse: 0.4541 - val_loss: 0.2961 - val_mse: 0.2961 - learning_rate: 5.0000e-04
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5769 - mse: 0.5769 - val_loss: 0.2992 - val_mse: 0.2992 - learning_rate: 5.0000e-04
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4941 - mse: 0.4941 - val_loss: 0.2978 - val_mse: 0.2978 - learning_rate: 5.0000e-04
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5168 - mse: 0.5168 - val_loss: 0.2958 - val_mse: 0.2958 - learning_rate: 5.0000e-04
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4160 - mse: 0.4160 - val_loss: 0.2967 - val_mse: 0.2967 - learning_rate: 5.0000e-04
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4673 - mse: 0.4673 - val_loss: 0.2998 - val_mse: 0.2998 - learning_rate: 5.0000e-04
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4057 - mse: 0.4057 - val_loss: 0.2994 - val_mse: 0.2994 - learning_rate: 5.0000e-04
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4930 - mse: 0.4930 - val_loss: 0.2962 - val_mse: 0.2962 - learning_rate: 5.0000e-04
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3976 - mse: 0.3976 - val_loss: 0.2975 - val_mse: 0.2975 - learning_rate: 2.5000e-04
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3816 - mse: 0.3816 - val_loss: 0.3006 - val_mse: 0.3006 - learning_rate: 2.5000e-04
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3771 - mse: 0.3771 - val_loss: 0.2985 - val_mse: 0.2985 - learning_rate: 2.5000e-04
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4948 - mse: 0.4948 - val_loss: 0.2970 - val_mse: 0.2970 - learning_rate: 2.5000e-04
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4224 - mse: 0.4224 - val_loss: 0.2950 - val_mse: 0.2950 - learning_rate: 2.5000e-04
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4028 - mse: 0.4028 - val_loss: 0.2942 - val_mse: 0.2942 - learning_rate: 2.5000e-04
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4491 - mse: 0.4491 - val_loss: 0.2947 - val_mse: 0.2947 - learning_rate: 2.5000e-04
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3774 - mse: 0.3774 - val_loss: 0.2966 - val_mse: 0.2966 - learning_rate: 2.5000e-04
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4337 - mse: 0.4337 - val_loss: 0.2985 - val_mse: 0.2985 - learning_rate: 2.5000e-04
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4262 - mse: 0.4262 - val_loss: 0.3029 - val_mse: 0.3029 - learning_rate: 2.5000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Final MSE (Test): 0.2604
# Final R2 score (Test): 0.6724

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test_actual, y=y_test_pred, alpha=0.5)
plt.plot([y_test_actual.min(), y_test_actual.max()], [y_test_actual.min(), y_test_actual.max()], 'r--')
plt.title('Actual vs Predicted Hospital Length of Stay')
plt.xlabel('Actual HLOS')
plt.ylabel('Predicted HLOS')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(hospital_df['hospital_length_of_stay'], bins=50, kde=True)
plt.title('Distribution of Hospital Length of Stay (HLOS)')
plt.xlabel('Hospital Length of Stay')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test_actual, y=y_test_pred, alpha=0.5)
plt.plot([y_test_actual.min(), y_test_actual.max()], [y_test_actual.min(), y_test_actual.max()], 'r--')  # Diagonal line
plt.title('Actual vs Predicted Hospital Length of Stay')
plt.xlabel('Actual HLOS')
plt.ylabel('Predicted HLOS')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss (MSE)')
plt.plot(history.history['val_loss'], label='Validation Loss (MSE)', linestyle='--')
plt.title('Training and Validation Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['mse'], label='Train MAE')
plt.plot(history.history['val_mse'], label='Validation MAE', linestyle='--')
plt.title('Training and Validation MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()

# %%
correlations = corr_matrix['hospital_length_of_stay'].abs().sort_values(ascending=False)
top_features = correlations[1:16].index.tolist()
plt.figure(figsize=(10, 6))
sns.barplot(x=correlations[top_features], y=top_features, palette='viridis')
plt.title('Top Features Correlated with Hospital Length of Stay')
plt.xlabel('Absolute Correlation with HLOS')
plt.ylabel('Features')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-174-715d1843db09>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlations[top_features], y=top_features, palette='viridis')
